# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
# how to print mathenatical expressions on plot
#https://matplotlib.org/users/mathtext.html

# %%
x = np.linspace(0,10,100)

# %%
plt.plot(x,np.sin(x),'-')

# %%
plt.plot(x,np.sin(x),'.')
plt.xlabel('$\Delta$')

# %%
x = np.arange(10)

# %%
y = np.arange(10)

# %%
plt.plot(x,y,'-')

# %%
plt.subplot(2,1,1)
plt.plot(x,y,'-')

plt.subplot(2,1,2)
plt.plot(y,x,'.')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'-')

plt.subplot(1,2,2)
plt.plot(y,x,'.')

# %%
fig , ax = plt.subplots(2)
ax[0].plot(y,x,'.')
ax[1].plot(y,x,'-')

# %%
x = np.linspace(0,10,100)

# %%
help(np.random)
